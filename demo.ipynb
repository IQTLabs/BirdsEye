# %%
from birdseye.mcts import * 
from birdseye.actions import *
from birdseye.sensor import * 
from birdseye.state import * 
from birdseye.env import RFEnv

# %%
N = 500
depth = 10
lambda_arg = 0.8 
num_runs = 100 
iterations = 2000
collision = -2
loss = -2

sensor = Drone()
actions = SimpleActions()
state = RFState()
env = RFEnv(sensor, actions, state)

run_mcts(env, N, depth, lambda_arg, num_runs, iterations, collision, loss, plotting=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-c50636bb94c2> in <module>
#      12 env = RFEnv(sensor, actions, state)
#      13
# ---> 14 run_mcts(env, N, depth, lambda_arg, num_runs, iterations, collision, loss, plotting=True)
#
# ~/BirdsEye/birdseye/mcts.py in run_mcts(env, N, DEPTH, lambda_arg, num_runs, iterations, COLLISION_REWARD, LOSS_REWARD, plotting, fig, ax)
#      56         run_start_time = datetime.now()
#      57         #global mcts_loss, mcts_coll, num_particles, DEPTH
# ---> 58         result = mcts_trial(env, DEPTH, 20, plotting, num_particles, fig=fig, ax=ax)
#      59         mcts_coll += result[2]
#      60         mcts_loss += result[3]
#
# ~/BirdsEye/birdseye/mcts_utils.py in mcts_trial(env, depth, c, plotting, iterations, fig, ax)
#     216
#     217         if plotting:
# --> 218             build_plots(true_state, belief, env.state.sensor_state, env.get_absolute_target(), env.get_absolute_particles(), time_step, fig, ax)
#     219
#     220         # TODO: flags for collision, lost track, end of simulation lost track
#
# ~/BirdsEye/birdseye/utils.py in build_plots(xp, belief, abs_sensor, abs_target, abs_particles, time_step, fig, ax)
#      85         ax.set_title('Absolute positions'.format(time_step), fontsize=16)
#      86
# ---> 87     plt.show()
#      88     r_error, theta_error, heading_error, centroid_distance_error, rmse  = tracking_error(abs_target, abs_particles)
#      89     print('r error = {}, theta error = {}, heading error = {}, centroid distance = {}, rmse = {}'.format(
#
# ~/.pyenv/versions/BirdsEye/lib/python3.8/site-packages/matplotlib/pyplot.py in show(*args, **kwargs)
#     351     """
#     352     _warn_if_gui_out_of_main_thread()
# --> 353     return _backend_mod.show(*args, **kwargs)
#     354
#     355
#
# ~/.pyenv/versions/BirdsEye/lib/python3.8/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      39             display(
#      40                 figure_manager.canvas.figure,
# ---> 41                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      42             )
#      43     finally:
#
# ~/.pyenv/versions/BirdsEye/lib/python3.8/site-packages/ipykernel/pylab/backend_inline.py in _fetch_figure_metadata(fig)
#     176     if _is_transparent(fig.get_facecolor()):
#     177         # the background is transparent
# --> 178         ticksLight = _is_light([label.get_color()
#     179                                 for axes in fig.axes
#     180                                 for axis in (axes.xaxis, axes.yaxis)
#
# ~/.pyenv/versions/BirdsEye/lib/python3.8/site-packages/ipykernel/pylab/backend_inline.py in <listcomp>(.0)
#     179                                 for axes in fig.axes
#     180                                 for axis in (axes.xaxis, axes.yaxis)
# --> 181                                 for label in axis.get_ticklabels()])
#     182         if ticksLight.size and (ticksLight == ticksLight[0]).all():
#     183             # there are one or more tick labels, all with the same lightness
#
# ~/.pyenv/versions/BirdsEye/lib/python3.8/site-packages/matplotlib/axis.py in get_ticklabels(self, minor, which)
#    1253         if minor:
#    1254             return self.get_minorticklabels()
# -> 1255         return self.get_majorticklabels()
#    1256
#    1257     def get_majorticklines(self):
#
# ~/.pyenv/versions/BirdsEye/lib/python3.8/site-packages/matplotlib/axis.py in get_majorticklabels(self)
#    1205     def get_majorticklabels(self):
#    1206         """Return this Axis' major tick labels, as a list of `~.text.Text`."""
# -> 1207         ticks = self.get_major_ticks()
#    1208         labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#    1209         labels2 = [tick.label2 for tick in ticks if tick.label2.get_visible()]
#
# ~/.pyenv/versions/BirdsEye/lib/python3.8/site-packages/matplotlib/axis.py in get_major_ticks(self, numticks)
#    1380         while len(self.majorTicks) < numticks:
#    1381             # Update the new tick label properties from the old.
# -> 1382             tick = self._get_tick(major=True)
#    1383             self.majorTicks.append(tick)
#    1384             self._copy_tick_props(self.majorTicks[0], tick)
#
# ~/.pyenv/versions/BirdsEye/lib/python3.8/site-packages/matplotlib/projections/polar.py in _get_tick(self, major)
#     683         else:
#     684             tick_kw = self._minor_tick_kw
# --> 685         return RadialTick(self.axes, 0, major=major, **tick_kw)
#     686
#     687     def _wrap_locator_formatter(self):
#
# ~/.pyenv/versions/BirdsEye/lib/python3.8/site-packages/matplotlib/projections/polar.py in __init__(self, *args, **kwargs)
#     525
#     526     def __init__(self, *args, **kwargs):
# --> 527         super().__init__(*args, **kwargs)
#     528         self.label1.set_rotation_mode('anchor')
#     529         self.label2.set_rotation_mode('anchor')
#
# ~/.pyenv/versions/BirdsEye/lib/python3.8/site-packages/matplotlib/axis.py in __init__(self, *args, **kwargs)
#     488
#     489     def __init__(self, *args, **kwargs):
# --> 490         super().__init__(*args, **kwargs)
#     491         # x in axes coords, y in data coords
#     492         self.tick1line.set(
#
# ~/.pyenv/versions/BirdsEye/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~/.pyenv/versions/BirdsEye/lib/python3.8/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     187             self._set_artist_props(artist)
#     188
# --> 189         self.update_position(loc)
#     190
#     191     @property
#
# ~/.pyenv/versions/BirdsEye/lib/python3.8/site-packages/matplotlib/projections/polar.py in update_position(self, loc)
#     586         super().update_position(loc)
#     587         axes = self.axes
# --> 588         thetamin = axes.get_thetamin()
#     589         thetamax = axes.get_thetamax()
#     590         direction = axes.get_theta_direction()
#
# ~/.pyenv/versions/BirdsEye/lib/python3.8/site-packages/matplotlib/projections/polar.py in get_thetamin(self)
#    1027     def get_thetamin(self):
#    1028         """Get the minimum theta limit in degrees."""
# -> 1029         return np.rad2deg(self.viewLim.xmin)
#    1030
#    1031     def set_thetalim(self, *args, **kwargs):
#
# ~/.pyenv/versions/BirdsEye/lib/python3.8/site-packages/matplotlib/axes/_base.py in viewLim(self)
#     649     @property
#     650     def viewLim(self):
# --> 651         self._unstale_viewLim()
#     652         return self._viewLim
#     653
#
# ~/.pyenv/versions/BirdsEye/lib/python3.8/site-packages/matplotlib/axes/_base.py in _unstale_viewLim(self)
#     637         # instead of on every axis.
#     638         scalex = any(ax._stale_viewlim_x
# --> 639                      for ax in self._shared_x_axes.get_siblings(self))
#     640         scaley = any(ax._stale_viewlim_y
#     641                      for ax in self._shared_y_axes.get_siblings(self))
#
# ~/.pyenv/versions/BirdsEye/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in get_siblings(self, a)
#     854         """Return all of the items joined with *a*, including itself."""
#     855         self.clean()
# --> 856         siblings = self._mapping.get(weakref.ref(a), [weakref.ref(a)])
#     857         return [x() for x in siblings]
#     858
#
# KeyboardInterrupt:

# %%
# Out:
# 2
