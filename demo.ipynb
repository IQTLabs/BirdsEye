# %%
# Imports
from birdseye.mcts import run_mcts
from birdseye.actions import get_action
from birdseye.sensor import get_sensor
from birdseye.state import get_state
from birdseye.env import RFEnv
from birdseye.method_utils import get_method

# Config class for . var access
class Config(dict):
    pass

# %%
# Method definitions
action_name = 'simpleactions'
sensor_name = 'drone'
state_name = 'rfstate'

sensor = get_sensor(sensor_name)
action = get_action(action_name)
state = get_state(state_name)

# Setup environment
env = RFEnv(sensor(), action(), state())

# Setup configuration object
config = Config()
# Default params
config.simulations = 500
config.depth = 10
config.lambda_arg = 0.8
config.trials = 100
config.iterations = 2000
config.collision = -2
config.loss = -2
config.plotting = True
# Out:
# Available Actions:
#   ID, Values
#    0   (-30, 1)
#    1   (-30, 2)
#    2   (0, 1)
#    3   (0, 2)
#    4   (30, 1)
#    5   (30, 2)

# %%
# Run MCTS
run_mcts(env=env, config=defaults)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-6139dcaa3f35> in <module>
#       1 # Run MCTS
# ----> 2 run_mcts(env=env, config=defaults)
#
# ~/lab41/projects/BirdsEye/BirdsEye_repo/birdseye/mcts.py in run_mcts(env, config, fig, ax)
#     103         run_start_time = datetime.now()
#     104         #global mcts_loss, mcts_coll, num_particles, DEPTH
# --> 105         result = mcts_trial(env, iterations, DEPTH, 20, plotting, simulations, fig=fig, ax=ax)
#     106         mcts_coll += result[2]
#     107         mcts_loss += result[3]
#
# ~/lab41/projects/BirdsEye/BirdsEye_repo/birdseye/mcts_utils.py in mcts_trial(env, num_iters, depth, c, plotting, simulations, fig, ax)
#     214
#     215         if plotting:
# ...
