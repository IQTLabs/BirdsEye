# %%
from birdseye.mcts import * 
from birdseye.actions import *
from birdseye.sensor import * 
from birdseye.env import RFEnv

# %%
N = 500
depth = 10
lambda_arg = 0.8 
num_runs = 100 
iterations = 2000
collision = -2
loss = -2

sensor = Drone()
actions = SimpleActions()
env = RFEnv(sensor, actions)

run_mcts(env, N, depth, lambda_arg, num_runs, iterations, collision, loss, plotting=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-551d29f4d3c6> in <module>
#      11 env = RFEnv(sensor, actions)
#      12
# ---> 13 run_mcts(env, N, depth, lambda_arg, num_runs, iterations, collision, loss, plotting=True)
#
# ~/BirdsEye/birdseye/mcts.py in run_mcts(env, N, DEPTH, lambda_arg, num_runs, iterations, COLLISION_REWARD, LOSS_REWARD, plotting, fig, ax)
#      54         run_start_time = datetime.now()
#      55         #global mcts_loss, mcts_coll, num_particles, DEPTH
# ---> 56         result = mcts_trial(env, DEPTH, 20, plotting, num_particles, fig=fig, ax=ax)
#      57         mcts_coll += result[2]
#      58         mcts_loss += result[3]
#
# ~/BirdsEye/birdseye/mcts_utils.py in mcts_trial(env, depth, c, plotting, iterations, fig, ax)
#     214
#     215         if plotting:
# ...

# %%
# Out:
# 2
