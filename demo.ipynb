# %%
from birdseye.mcts import * 
from birdseye.actions import *
from birdseye.sensor import * 
from birdseye.state import * 
from birdseye.env import RFEnv

# %%
N = 500
depth = 10
lambda_arg = 0.8 
num_runs = 100 
iterations = 2000
collision = -2
loss = -2

sensor = Drone()
actions = SimpleActions()
state = RFState()
env = RFEnv(sensor, actions, state)

run_mcts(env, N, depth, lambda_arg, num_runs, iterations, collision, loss, plotting=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-c50636bb94c2> in <module>
#      12 env = RFEnv(sensor, actions, state)
#      13
# ---> 14 run_mcts(env, N, depth, lambda_arg, num_runs, iterations, collision, loss, plotting=True)
#
# ~/lab41/projects/BirdsEye/BirdsEye_repo/birdseye/mcts.py in run_mcts(env, N, DEPTH, lambda_arg, num_runs, iterations, COLLISION_REWARD, LOSS_REWARD, plotting, fig, ax)
#      54         run_start_time = datetime.now()
#      55         #global mcts_loss, mcts_coll, num_particles, DEPTH
# ---> 56         result = mcts_trial(env, DEPTH, 20, plotting, num_particles, fig=fig, ax=ax)
#      57         mcts_coll += result[2]
#      58         mcts_loss += result[3]
#
# ~/lab41/projects/BirdsEye/BirdsEye_repo/birdseye/mcts_utils.py in mcts_trial(env, depth, c, plotting, iterations, fig, ax)
#     195
#     196         # select an action
# --> 197         (Q, N, action) = select_action(env, Q, N, belief, depth, c, iterations)
#     198
#     199         # take action; get next true state, obs, and reward
#
# ~/lab41/projects/BirdsEye/BirdsEye_repo/birdseye/mcts_utils.py in select_action(env, Q, N, belief, depth, c, iterations)
#     133
#     134         # simulate
# --> 135         simulate(env, Q, N, state.astype(float), history, depth, c)
#     136
#     137         counter += 1
#
# ~/lab41/projects/BirdsEye/BirdsEye_repo/birdseye/mcts_utils.py in simulate(env, Q, N, state, history, depth, c)
#      97
#      98     # take action; get new state, observation, and reward
# ---> 99     state_prime = env.state.update_state(state, action)
#     100     observation = env.sensor.observation(state_prime)
#     101     reward = env.state.reward_func(state_prime, search_action_index)
#
# ~/lab41/projects/BirdsEye/BirdsEye_repo/birdseye/state.py in update_state(self, state_vars, control)
#      83         crs = crs % 360
#      84
# ---> 85         x, y = pol2cart(r, np.radians(theta))
#      86
#      87         dx, dy = pol2cart(TGT_SPD, np.radians(crs))
#
# ~/lab41/projects/BirdsEye/BirdsEye_repo/birdseye/utils.py in pol2cart(rho, phi)
#      10 # Some transform functions
#      11 def pol2cart(rho, phi):
# ---> 12     x = rho * np.cos(phi)
#      13     y = rho * np.sin(phi)
#      14     return(x, y)
#
# KeyboardInterrupt:

# %%
# Out:
# 2
