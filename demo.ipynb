# %%
from birdseye.mcts import * 
from birdseye.sensor import *

# %%
N = 500
depth = 10
lambda_arg = 0.8 
num_runs = 100 
iterations = 2000
collision = -2
loss = -2

sensor = Drone()

run_mcts(sensor, N, depth, lambda_arg, num_runs, iterations, collision, loss, plotting=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-2045f10321db> in <module>
#       9 sensor = Drone()
#      10
# ---> 11 run_mcts(sensor, N, depth, lambda_arg, num_runs, iterations, collision, loss, plotting=True)
#
# ~/BirdsEye/birdseye/mcts.py in run_mcts(sensor, N, DEPTH, lambda_arg, num_runs, iterations, COLLISION_REWARD, LOSS_REWARD, plotting, fig, ax)
#      50         run_start_time = datetime.now()
#      51         #global mcts_loss, mcts_coll, num_particles, DEPTH
# ---> 52         result = mcts_trial(sensor, DEPTH, 20, plotting, num_particles, fig=fig, ax=ax)
#      53         mcts_coll += result[2]
#      54         mcts_loss += result[3]
#
# ~/BirdsEye/birdseye/mcts_utils.py in mcts_trial(sensor, depth, c, plotting, num_particles, iterations, fig, ax)
#     367
#     368         # select an action
# --> 369         (Q, N, action) = select_action(sensor, Q, N, belief, depth, c, iterations)
#     370
#     371         # take action; get next true state, obs, and reward
#
# ~/BirdsEye/birdseye/mcts_utils.py in select_action(sensor, Q, N, belief, depth, c, iterations)
#     247
#     248         # simulate
# --> 249         simulate(sensor, Q, N, state.astype(float), history, depth, c)
#     250
#     251         counter+=1
#
# ~/BirdsEye/birdseye/mcts_utils.py in simulate(sensor, Q, N, state, history, depth, c)
#     207     state_prime = f2(state, action)
#     208     observation = sensor.observation(state_prime)
# --> 209     reward = r(tuple(state_prime), action_to_index(action))
#     210
#     211     # recursive call after taking action and getting observation
#
# ~/BirdsEye/birdseye/mcts_utils.py in action_to_index(a)
#     100 #returns action given an index
#     101 def action_to_index(a):
# --> 102     return int(np.trunc(2*(a[0] / 30 + 1) + a[1]))-1
#     103
#     104
#
# KeyboardInterrupt:
