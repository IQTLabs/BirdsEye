# %%
# Imports
from birdseye.mcts import run_mcts
from birdseye.actions import get_action
from birdseye.sensor import get_sensor
from birdseye.state import get_state
from birdseye.env import RFEnv
from birdseye.method_utils import get_method

# Config class for . var access
class Config(dict):
    pass

# %%
# Method definitions
action_name = 'simpleactions'
sensor_name = 'drone'
state_name = 'rfstate'

sensor = get_sensor(sensor_name)
action = get_action(action_name)
state = get_state(state_name)

# Setup environment
env = RFEnv(sensor(), action(), state())

# Setup configuration object
config = Config()
# Default params
config.simulations = 500
config.depth = 10
config.lambda_arg = 0.8
config.trials = 100
config.iterations = 2000
config.collision = -2
config.loss = -2
config.plotting = True

# %%
# Run MCTS
run_mcts(env=env, config=config)
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-79f99a10630f> in <module>
#       1 # Run MCTS
# ----> 2 run_mcts(env=env, config=config)
#
# ~/BirdsEye/birdseye/mcts.py in run_mcts(env, config, fig, ax, global_start_time)
#      92         run_start_time = datetime.now()
#      93         #global mcts_loss, mcts_coll, num_particles, DEPTH
# ---> 94         result = mcts_trial(env, iterations, DEPTH, 20, plotting, simulations, fig=fig, ax=ax, results=results)
#      95         run_time = datetime.now()-run_start_time
#      96         run_data.append([datetime.now(), run_time] + result[1:])
#
# ~/BirdsEye/birdseye/mcts_utils.py in mcts_trial(env, num_iters, depth, c, plotting, simulations, fig, ax, results)
#     263
#     264         if results is not None and results.plotting:
# --> 265             results.build_plots(env.state.target_state, belief, env.state.sensor_state, env.get_absolute_target(), env.get_absolute_particles(), time_step, fig, ax)
#     266
#     267         # Save results to output arrays
#
# ~/BirdsEye/birdseye/utils.py in build_plots(self, xp, belief, abs_sensor, abs_target, abs_particles, time_step, fig, ax)
#     192             target_r.append(self.abs_target_hist[10*(i+1)-1][0])
#     193             target_theta.append(np.radians(self.abs_target_hist[10*(i+1)-1][1]))
# --> 194             sensor_x[i], sensor_y[i] = pol2cart(sensor_r, sensor_theta)
#     195             target_x[i], target_y[i] = pol2cart(target_r, target_theta)
#     196
#
# IndexError: list assignment index out of range
