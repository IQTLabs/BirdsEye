# %%
import torch
from birdseye.sensor import * 
from birdseye.actions import *
from birdseye.env import RFEnv
from birdseye.rl_common.util import scale_ob
from birdseye.rl_common.models import CNN, MLP
from birdseye.mcts_utils import build_plot

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
save_path = 'checkpoints'
checkpoint_num = 10000
model_state_dict, optim_state_dict = torch.load('{}/{}.checkpoint'.format(save_path, checkpoint_num))


sensor = Drone()
actions = SimpleActions()
env = RFEnv(sensor, actions)

dueling = True
atom_num = 1
ob_scale = 1
policy_dim = len(env.actions.action_space)
in_dim = (1, 100, 100)
network = CNN(in_dim, policy_dim, atom_num, dueling)

network.load_state_dict(model_state_dict)
# Out:
# <All keys matched successfully>

# %%
num_steps = 5000

o = env.reset()

for i in range(num_steps): 
    with torch.no_grad():
        ob = scale_ob(np.expand_dims(o, 0), device, ob_scale)
        q = network(ob)

        a = q.argmax(1).cpu().numpy()[0]
        print(a)
        o_, r, done, info = env.step(a)

        build_plot(env.true_state, env.pf.particles)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-122776e6f0a3> in <module>
#      12         o_, r, done, info = env.step(a)
#      13
# ---> 14         build_plot(env.true_state, env.pf.particles)
#
# ~/BirdsEye/birdseye/mcts_utils.py in build_plot(xp, belief, fig, ax, time_step)
#     453     #ax.plot(plot_theta, plot_r, 'ro')
#     454     #ax.plot(plot_x_theta, plot_x_r, 'bo')
# --> 455     plt.show()
#     456     #fig.canvas.draw()
#     457     #fig.clf()
#
# ~/.pyenv/versions/BirdsEye/lib/python3.8/site-packages/matplotlib/pyplot.py in show(*args, **kwargs)
#     351     """
#     352     _warn_if_gui_out_of_main_thread()
# --> 353     return _backend_mod.show(*args, **kwargs)
#     354
#     355
#
# ~/.pyenv/versions/BirdsEye/lib/python3.8/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      37     try:
# ...
