# %%
from mcts import *

# %%
N = 500
depth = 10
lambda_arg = 0.8 
num_runs = 100 
iterations = 2000
collision = -2
loss = -2


run_mcts(N, depth, lambda_arg, num_runs, iterations, collision, loss, plotting=True)
