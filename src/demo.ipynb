# %%
from mcts import *

# %%
N = 500
depth = 10
lambda_arg = 0.8 
num_runs = 100 
iterations = 2000
collision = -2
loss = -2


run_mcts(N, depth, lambda_arg, num_runs, iterations, collision, loss, plotting=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-a506307d9ea7> in <module>
#       8
#       9
# ---> 10 run_mcts(N, depth, lambda_arg, num_runs, iterations, collision, loss, plotting=True)
#
# ~/BirdsEye/src/mcts.py in run_mcts(N, DEPTH, lambda_arg, num_runs, iterations, COLLISION_REWARD, LOSS_REWARD, plotting, fig, ax)
#      51         run_start_time = datetime.now()
#      52         #global mcts_loss, mcts_coll, num_particles, DEPTH
# ---> 53         result = mcts_trial(DEPTH, 20, plotting, num_particles, fig=fig, ax=ax)
#      54         mcts_coll += result[2]
#      55         mcts_loss += result[3]
#
# ~/BirdsEye/src/mcts_utils.py in mcts_trial(depth, c, plotting, num_particles, iterations, fig, ax)
#     350
#     351         # select an action
# --> 352         (Q, N, action) = select_action(Q, N, belief, depth, c, iterations)
#     353
# ...
