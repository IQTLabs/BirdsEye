# %%
import matplotlib.pyplot as plt
from birdseye.results import *

# %% [markdown]
# #  MCTS vs DQN
# ## starting position = 80

# %%
target_start = 80
sensors = ['drone', 'signalstrength']
rewards = ['range_reward', 'entropy_collision_reward']

for s in sensors: 
    for r in rewards: 
        config = {'datetime_start': '2021-06-18T00:00:00', 'reward':r, 'sensor':s, 'target_start': target_start, 'target_speed':1 }
        single_plot(config, variance_bars=True)
# Out:
# MCTS, Bearings Sensor, State Dependent Reward, inference time=7.77e-02s
# DQN, Bearings Sensor, State Dependent Reward, inference time=6.05e-04s
# Speedup (MCTS/DQN) = 128.4749158537281x
# MCTS, Bearings Sensor, Belief Dependent Reward, inference time=3.66e+00s
# DQN, Bearings Sensor, Belief Dependent Reward, inference time=6.05e-04s
# Speedup (MCTS/DQN) = 6044.68275982071x
# MCTS, Signal Strength Sensor, State Dependent Reward, inference time=7.04e-02s
# DQN, Signal Strength Sensor, State Dependent Reward, inference time=6.03e-04s
# Speedup (MCTS/DQN) = 116.73262595131352x
# MCTS, Signal Strength Sensor, Belief Dependent Reward, inference time=2.17e+00s
# DQN, Signal Strength Sensor, Belief Dependent Reward, inference time=6.08e-04s
# Speedup (MCTS/DQN) = 3560.1464907501386x

# %% [markdown]
# # target_start = 50

# %%
target_start = 50
sensors = ['drone', 'signalstrength']
rewards = ['range_reward', 'entropy_collision_reward']

for s in sensors: 
    for r in rewards: 
        config = {'datetime_start': '2021-06-18T00:00:00', 'reward':r, 'sensor':s, 'target_start': target_start, 'target_speed':1 }
        single_plot(config, variance_bars=True)
# Out:
# MCTS, Bearings Sensor, State Dependent Reward, inference time=1.00e+01s
# DQN, Bearings Sensor, State Dependent Reward, inference time=1.00e+01s
# Speedup (MCTS/DQN) = 1.0x
# MCTS, Bearings Sensor, Belief Dependent Reward, inference time=1.00e+01s
# DQN, Bearings Sensor, Belief Dependent Reward, inference time=1.00e+01s
# Speedup (MCTS/DQN) = 1.0x
# MCTS, Signal Strength Sensor, State Dependent Reward, inference time=1.00e+01s
# DQN, Signal Strength Sensor, State Dependent Reward, inference time=1.00e+01s
# Speedup (MCTS/DQN) = 1.0x
# MCTS, Signal Strength Sensor, Belief Dependent Reward, inference time=1.00e+01s
# DQN, Signal Strength Sensor, Belief Dependent Reward, inference time=1.00e+01s
# Speedup (MCTS/DQN) = 1.0x

# %% [markdown]
# # target_start = 75

# %%
target_start = 75
sensors = ['drone', 'signalstrength']
rewards = ['range_reward', 'entropy_collision_reward']

for s in sensors: 
    for r in rewards: 
        config = {'datetime_start': '2021-06-19T00:00:00', 'reward':r, 'sensor':s, 'target_start': target_start, 'target_speed':1 }
        single_plot(config, variance_bars=True)
# Out:
# MCTS, Bearings Sensor, State Dependent Reward, inference time=1.00e+01s
# DQN, Bearings Sensor, State Dependent Reward, inference time=1.00e+01s
# Speedup (MCTS/DQN) = 1.0x
# MCTS, Bearings Sensor, Belief Dependent Reward, inference time=1.00e+01s
# DQN, Bearings Sensor, Belief Dependent Reward, inference time=1.00e+01s
# Speedup (MCTS/DQN) = 1.0x
# MCTS, Signal Strength Sensor, State Dependent Reward, inference time=1.00e+01s
# DQN, Signal Strength Sensor, State Dependent Reward, inference time=1.00e+01s
# Speedup (MCTS/DQN) = 1.0x
# MCTS, Signal Strength Sensor, Belief Dependent Reward, inference time=1.00e+01s
# DQN, Signal Strength Sensor, Belief Dependent Reward, inference time=1.00e+01s
# Speedup (MCTS/DQN) = 1.0x

# %% [markdown]
# # target_start = 90, target_speed = 2

# %%
target_start = 90
sensors = ['drone', 'signalstrength']
rewards = ['range_reward', 'entropy_collision_reward']

for s in sensors: 
    for r in rewards: 
        config = {'datetime_start': '2021-06-19T00:00:00', 'reward':r, 'sensor':s, 'target_start': target_start, 'target_speed':2 }
        single_plot(config, variance_bars=True)
# Out:
# MCTS, Bearings Sensor, State Dependent Reward, inference time=1.00e+01s
# DQN, Bearings Sensor, State Dependent Reward, inference time=1.00e+01s
# Speedup (MCTS/DQN) = 1.0x
# MCTS, Bearings Sensor, Belief Dependent Reward, inference time=1.00e+01s
# DQN, Bearings Sensor, Belief Dependent Reward, inference time=1.00e+01s
# Speedup (MCTS/DQN) = 1.0x
# MCTS, Signal Strength Sensor, State Dependent Reward, inference time=1.00e+01s
# DQN, Signal Strength Sensor, State Dependent Reward, inference time=1.00e+01s
# Speedup (MCTS/DQN) = 1.0x
# MCTS, Signal Strength Sensor, Belief Dependent Reward, inference time=1.00e+01s
# DQN, Signal Strength Sensor, Belief Dependent Reward, inference time=1.00e+01s
# Speedup (MCTS/DQN) = 1.0x

# %% [markdown]
# # target_start = 100

# %%
target_start = 100
sensors = ['drone', 'signalstrength']
rewards = ['range_reward', 'entropy_collision_reward']

for s in sensors: 
    for r in rewards: 
        config = {'datetime_start': '2021-06-19T00:00:00', 'reward':r, 'sensor':s, 'target_start': target_start, 'target_speed':1 }
        single_plot(config, metric='centroid_err', variance_bars=True)
# Out:
# MCTS, Bearings Sensor, State Dependent Reward, inference time=1.00e+01s
# DQN, Bearings Sensor, State Dependent Reward, inference time=1.00e+01s
# Speedup (MCTS/DQN) = 1.0x
# MCTS, Bearings Sensor, Belief Dependent Reward, inference time=1.00e+01s
# DQN, Bearings Sensor, Belief Dependent Reward, inference time=1.00e+01s
# Speedup (MCTS/DQN) = 1.0x
# MCTS, Signal Strength Sensor, State Dependent Reward, inference time=1.00e+01s
# DQN, Signal Strength Sensor, State Dependent Reward, inference time=1.00e+01s
# Speedup (MCTS/DQN) = 1.0x
# MCTS, Signal Strength Sensor, Belief Dependent Reward, inference time=1.00e+01s
# DQN, Signal Strength Sensor, Belief Dependent Reward, inference time=1.00e+01s
# Speedup (MCTS/DQN) = 1.0x

# %% [markdown]
# # target_start = 125

# %%
target_start = 125
sensors = ['drone', 'signalstrength']
rewards = ['range_reward', 'entropy_collision_reward']

for s in sensors: 
    for r in rewards: 
        config = {'datetime_start': '2021-06-19T00:00:00', 'reward':r, 'sensor':s, 'target_start': target_start, 'target_speed':1 }
        single_plot(config, variance_bars=True)
# Out:
# MCTS, Bearings Sensor, State Dependent Reward, inference time=1.00e+01s
# DQN, Bearings Sensor, State Dependent Reward, inference time=1.00e+01s
# Speedup (MCTS/DQN) = 1.0x
# MCTS, Bearings Sensor, Belief Dependent Reward, inference time=1.00e+01s
# DQN, Bearings Sensor, Belief Dependent Reward, inference time=1.00e+01s
# Speedup (MCTS/DQN) = 1.0x
# MCTS, Signal Strength Sensor, State Dependent Reward, inference time=1.00e+01s
# DQN, Signal Strength Sensor, State Dependent Reward, inference time=1.00e+01s
# Speedup (MCTS/DQN) = 1.0x
# MCTS, Signal Strength Sensor, Belief Dependent Reward, inference time=1.00e+01s
# DQN, Signal Strength Sensor, Belief Dependent Reward, inference time=1.00e+01s
# Speedup (MCTS/DQN) = 1.0x

# %% [markdown]
# # target_start = 150

# %%
target_start = 150
sensors = ['drone', 'signalstrength']
rewards = ['range_reward', 'entropy_collision_reward']

for s in sensors: 
    for r in rewards: 
        config = {'datetime_start': '2021-05-09T00:00:00', 'reward':r, 'sensor':s, 'target_start': target_start, 'target_speed':1 }
        single_plot(config, variance_bars=True)
# Out:
# No handles with labels found to put in legend.
# Speedup (MCTS/DQN) = 1.0x
# No handles with labels found to put in legend.
# Speedup (MCTS/DQN) = 1.0x
# No handles with labels found to put in legend.
# Speedup (MCTS/DQN) = 1.0x
# No handles with labels found to put in legend.
# Speedup (MCTS/DQN) = 1.0x

# %% [markdown]
# # Each method (MCTS, DQN each, combined) comparing several starting positions (3 plots)
#
# ## starting positions = [50, 150]

# %%
sensors = ['drone', 'signalstrength']
rewards = ['range_reward', 'entropy_collision_reward']

for s in sensors: 
    for r in rewards: 
        config = {'datetime_start': '2021-06-19T00:00:00',  'reward':r, 'sensor':s,  'target_speed':1, 'target_start':['75','80']}
        starting_position_plots(config)

# %% [markdown]
# # 	Sensor type same methods & starting conditions (MCTS, DQN each, combined) (3 plots)

# %%
sensors = ['drone', 'signalstrength']
rewards = ['range_reward', 'entropy_collision_reward']
target_speeds = [0,1,2]

for s in sensors: 
    config = {'datetime_start': '2021-06-19T00:00:00','sensor':s, 'target_start':'125', 'target_speed':1 }
    single_plot(config, metric='centroid_err', limit=2)
# Out:
# MCTS, Bearings Sensor, Belief Dependent Reward, inference time=1.00e+01s
# MCTS, Bearings Sensor, State Dependent Reward, inference time=1.00e+01s
# DQN, Bearings Sensor, Belief Dependent Reward, inference time=1.00e+01s
# DQN, Bearings Sensor, State Dependent Reward, inference time=1.00e+01s
# Speedup (MCTS/DQN) = 1.0x
# MCTS, Signal Strength Sensor, Belief Dependent Reward, inference time=1.00e+01s
# MCTS, Signal Strength Sensor, State Dependent Reward, inference time=1.00e+01s
# DQN, Signal Strength Sensor, Belief Dependent Reward, inference time=1.00e+01s
# DQN, Signal Strength Sensor, State Dependent Reward, inference time=1.00e+01s
# Speedup (MCTS/DQN) = 1.0x

# %% [markdown]
# # Reward type (3 plots)

# %%
sensors = ['drone', 'signalstrength']
rewards = ['range_reward', 'entropy_collision_reward']
target_speeds = [0,1,2]

for r in rewards: 
    config = {'reward':r, 'target_start':'100', 'target_speed':1 }
    single_plot(config)
# Out:
# MCTS, Bearings Sensor, State Dependent Reward, inference time=1.00e+01s
# DQN, Bearings Sensor, State Dependent Reward, inference time=1.00e+01s
# Speedup (MCTS/DQN) = 1.0x
# MCTS, Bearings Sensor, Belief Dependent Reward, inference time=1.00e+01s
# DQN, Bearings Sensor, Belief Dependent Reward, inference time=1.00e+01s
# Speedup (MCTS/DQN) = 1.0x
