# %%
import matplotlib.pyplot as plt
from birdseye.results import *

# %%
# figure 4


print('Captions describe plots starting at top left and moving clockwise \n')
target_start = 78
sensors = ['drone', 'signalstrength']
rewards = ['range_reward', 'entropy_collision_reward']

fig = plt.figure(figsize=(20,16))
i = 1
for s in sensors: 
    for r in rewards: 
        config = {'datetime_start': '2021-06-18T00:00:00', 'reward':r, 'sensor':s, 'target_start': target_start, 'target_speed':1 }
        ax1 = plt.subplot(2,2,i)
        single_plot_combined(ax1, config, variance_bars=True)
        i += 1 
        
plt.show()

# %%
# figure 5
sensors = ['drone', 'signalstrength']
rewards = ['range_reward', 'entropy_collision_reward']

for s in sensors: 
    for r in rewards: 
        config = {'datetime_start': '2021-06-19T00:00:00',  'reward':r, 'sensor':s,  'target_speed':1, 'target_start':['75','100', '125']}
        starting_position_plots(config, limit=3)

# %%
# figure 6
        
print('Captions describe plots starting at top left and moving clockwise \n')
target_start = 78
sensors = ['drone', 'signalstrength']
rewards = ['range_reward', 'entropy_collision_reward']

fig = plt.figure(figsize=(20,16))
i = 1
for s in sensors: 
    for r in rewards: 
        config = {'datetime_start': '2021-06-18T00:00:00', 'reward':r, 'sensor':s, 'target_start': target_start, 'target_speed':1 }
        ax1 = plt.subplot(2,2,i)
        panel_dual_axis(ax1, config, metric1='r_err', metric2='theta_err', limit=2, variance_bars=False)
        i += 1 
plt.subplots_adjust(wspace=0.25)

plt.show()

# %%
# figure 7
print('Captions describe plots starting at top left and moving clockwise \n')
target_start = 78
sensors = ['drone', 'signalstrength']
rewards = ['range_reward', 'entropy_collision_reward']

fig = plt.figure(figsize=(20,16))
plt.tight_layout(pad=1.8, w_pad=1.8, h_pad=2.0)
i = 1
for s in sensors: 
    for r in rewards: 
        config = {'datetime_start': '2021-06-18T00:00:00', 'reward':r, 'sensor':s, 'target_start': target_start, 'target_speed':1 }
        ax1 = plt.subplot(2,2,i)
        single_plot_combined_cov(ax1, config, metric='collisions', variance_bars=False, y_lim=10, limit=2)
        i += 1 
plt.subplots_adjust(wspace=0.25)
plt.show()
# Out:
# Captions describe plots starting at top left and moving clockwise
#
# color bar fix
# /home/ltindall/BirdsEye/birdseye/results.py:308: RuntimeWarning: invalid value encountered in sqrt
#   pf_cov = np.sqrt(pf_cov)
# MCTS, Bearings Sensor, State Dependent Reward, inference time=7.99e-02s
# /home/ltindall/BirdsEye/birdseye/results.py:352: RuntimeWarning: invalid value encountered in sqrt
#   pf_cov = np.sqrt(pf_cov)
# DQN, Bearings Sensor, State Dependent Reward, inference time=7.04e-04s
# Speedup (MCTS/DQN) = 113.57482597476239x
# ======================================
# color bar fix
# /home/ltindall/BirdsEye/birdseye/results.py:308: RuntimeWarning: invalid value encountered in sqrt
#   pf_cov = np.sqrt(pf_cov)
# MCTS, Bearings Sensor, Belief Dependent Reward, inference time=3.73e+00s
# /home/ltindall/BirdsEye/birdseye/results.py:352: RuntimeWarning: invalid value encountered in sqrt
#   pf_cov = np.sqrt(pf_cov)
# DQN, Bearings Sensor, Belief Dependent Reward, inference time=7.19e-04s
# Speedup (MCTS/DQN) = 5190.980152477239x
# ======================================
# color bar fix
# /home/ltindall/BirdsEye/birdseye/results.py:308: RuntimeWarning: invalid value encountered in sqrt
#   pf_cov = np.sqrt(pf_cov)
# MCTS, Signal Strength Sensor, State Dependent Reward, inference time=7.18e-02s
# /home/ltindall/BirdsEye/birdseye/results.py:352: RuntimeWarning: invalid value encountered in sqrt
#   pf_cov = np.sqrt(pf_cov)
# DQN, Signal Strength Sensor, State Dependent Reward, inference time=7.18e-04s
# Speedup (MCTS/DQN) = 100.09092901356848x
# ======================================
# color bar fix
# /home/ltindall/BirdsEye/birdseye/results.py:308: RuntimeWarning: invalid value encountered in sqrt
#   pf_cov = np.sqrt(pf_cov)
# MCTS, Signal Strength Sensor, Belief Dependent Reward, inference time=2.22e+00s
# /home/ltindall/BirdsEye/birdseye/results.py:352: RuntimeWarning: invalid value encountered in sqrt
#   pf_cov = np.sqrt(pf_cov)
# DQN, Signal Strength Sensor, Belief Dependent Reward, inference time=6.69e-04s
# Speedup (MCTS/DQN) = 3319.6155003663876x
# ======================================

# %% [markdown]
# #  MCTS vs DQN
# ## starting position = 80

# %%
print('Captions describe plots starting at top left and moving clockwise \n')
target_start = 78
sensors = ['drone', 'signalstrength']
rewards = ['range_reward', 'entropy_collision_reward']

fig = plt.figure(figsize=(16,24))
plt.tight_layout(pad=1.8, w_pad=1.8, h_pad=2.0)
i = 1
for s in sensors: 
    for r in rewards: 
        config = {'datetime_start': '2021-06-18T00:00:00', 'reward':r, 'sensor':s, 'target_start': target_start, 'target_speed':1 }
        
        ax1 = plt.subplot(4,2,i)
        single_plot_combined_cov(ax1, config, dqn=False, metric='collisions', variance_bars=True, y_lim=10, limit=2)
        i += 1 
        ax1 = plt.subplot(4,2,i)
        single_plot_combined_cov(ax1, config, mcts=False, metric='collisions', variance_bars=True, y_lim=10, limit=2)
        i += 1 
plt.subplots_adjust(wspace=0.30)
plt.show()

# %%
        
print('Captions describe plots starting at top left and moving clockwise \n')
target_start = 78
sensors = ['drone', 'signalstrength']
rewards = ['range_reward', 'entropy_collision_reward']

fig = plt.figure(figsize=(16,24))
i = 1
for s in sensors: 
    for r in rewards: 
        config = {'datetime_start': '2021-06-18T00:00:00', 'reward':r, 'sensor':s, 'target_start': target_start, 'target_speed':1 }
        
        ax1 = plt.subplot(4,2,i)
        panel_dual_axis(ax1, config, dqn=False, metric1='r_err', metric2='theta_err',variance_bars=True, limit=2)
        i += 1 
        ax1 = plt.subplot(4,2,i)
        panel_dual_axis(ax1, config, mcts=False, metric1='r_err', metric2='theta_err',variance_bars=True, limit=2)
        i += 1 
plt.subplots_adjust(wspace=0.30)
plt.subplots_adjust(hspace=0.25)
plt.show()

# %%
print('Captions describe plots starting at top left and moving clockwise \n')
target_start = 78
sensors = ['drone', 'signalstrength']
rewards = ['range_reward', 'entropy_collision_reward']

fig = plt.figure(figsize=(20,16))
i = 1
for s in sensors: 
        config = {'datetime_start': '2021-06-18T00:00:00', 'sensor':s, 'target_start': target_start, 'target_speed':1 }
        ax1 = plt.subplot(2,2,i)
        single_plot_var(ax1, config, metric='r', variance_bars=False, y_lim=10, limit=2)
        i += 1 

plt.show()

# %%
print('Captions describe plots starting at top left and moving clockwise \n')
target_start = 78
sensors = ['drone', 'signalstrength']
rewards = ['range_reward', 'entropy_collision_reward']

fig = plt.figure(figsize=(20,16))
i = 1
for s in sensors: 
        config = {'datetime_start': '2021-06-18T00:00:00', 'sensor':s, 'target_start': target_start, 'target_speed':1 }
        ax1 = plt.subplot(2,2,i)
        single_plot_var(ax1, config, metric='theta', variance_bars=False, y_lim=10, limit=2)
        i += 1 

plt.show()

# %% [markdown]
# # figure 6

# %%
        
print('Captions describe plots starting at top left and moving clockwise \n')
target_start = 78
sensors = ['drone', 'signalstrength']
rewards = ['range_reward', 'entropy_collision_reward']

fig = plt.figure(figsize=(20,16))
i = 1
for s in sensors: 
    for r in rewards: 
        config = {'datetime_start': '2021-06-18T00:00:00', 'reward':r, 'sensor':s, 'target_start': target_start, 'target_speed':1 }
        ax1 = plt.subplot(2,2,i)
        panel_dual_axis(ax1, config, metric1='r_err', metric2='theta_err', limit=2, variance_bars=False)
        i += 1 
plt.subplots_adjust(wspace=0.25)

plt.show()

# %%
        
print('Captions describe plots starting at top left and moving clockwise \n')
target_start = 78
sensors = ['drone', 'signalstrength']
rewards = ['range_reward', 'entropy_collision_reward']

fig = plt.figure(figsize=(20,16))
i = 1
for s in sensors: 
    for r in rewards: 
        config = {'datetime_start': '2021-06-18T00:00:00', 'reward':r, 'sensor':s, 'target_start': target_start, 'target_speed':1 }
        ax1 = plt.subplot(2,2,i)
        panel_dual_axis(ax1, config, metric1='r_err', metric2='theta_err', limit=2)
        i += 1 
plt.subplots_adjust(wspace=0.25)

plt.show()

# %%
print('Captions describe plots starting at top left and moving clockwise \n')
target_start = 78
sensors = ['drone', 'signalstrength']
rewards = ['range_reward', 'entropy_collision_reward']

fig = plt.figure(figsize=(20,16))
i = 1
for s in sensors: 
    for r in rewards: 
        config = {'datetime_start': '2021-06-18T00:00:00', 'reward':r, 'sensor':s, 'target_start': target_start, 'target_speed':1 }
        ax1 = plt.subplot(2,2,i)
        single_plot_var(ax1, config, metric='r', variance_bars=True, y_lim=10)
        i += 1 

plt.show()

# %%
print('Captions describe plots starting at top left and moving clockwise \n')
target_start = 78
sensors = ['drone', 'signalstrength']
rewards = ['range_reward', 'entropy_collision_reward']

fig = plt.figure(figsize=(20,16))
i = 1
for s in sensors: 
    for r in rewards: 
        config = {'datetime_start': '2021-06-18T00:00:00', 'reward':r, 'sensor':s, 'target_start': target_start, 'target_speed':1 }
        ax1 = plt.subplot(2,2,i)
        single_plot_var(ax1, config, metric='theta', variance_bars=True, y_lim=10)
        i += 1 

plt.show()

# %% [markdown]
# # figure 7

# %%
print('Captions describe plots starting at top left and moving clockwise \n')
target_start = 78
sensors = ['drone', 'signalstrength']
rewards = ['range_reward', 'entropy_collision_reward']

fig = plt.figure(figsize=(20,16))
plt.tight_layout(pad=1.8, w_pad=1.8, h_pad=2.0)
i = 1
for s in sensors: 
    for r in rewards: 
        config = {'datetime_start': '2021-06-18T00:00:00', 'reward':r, 'sensor':s, 'target_start': target_start, 'target_speed':1 }
        ax1 = plt.subplot(2,2,i)
        single_plot_combined_cov(ax1, config, metric='collisions', variance_bars=True, y_lim=10, limit=2)
        i += 1 
plt.subplots_adjust(wspace=0.25)
plt.show()

# %%
print('Captions describe plots starting at top left and moving clockwise \n')
target_start = 80
sensors = ['drone', 'signalstrength']
rewards = ['range_reward', 'entropy_collision_reward']

fig = plt.figure(figsize=(20,16))
i = 1
for s in sensors: 
    for r in rewards: 
        config = {'datetime_start': '2021-06-18T00:00:00', 'reward':r, 'sensor':s, 'target_start': target_start, 'target_speed':1 }
        ax1 = plt.subplot(2,2,i)
        single_plot_combined(ax1, config, metric='collisions', variance_bars=True, y_lim=10)
        i += 1 
        
plt.show()

# %%
print('Captions describe plots starting at top left and moving clockwise \n')
target_start = 78
sensors = ['drone', 'signalstrength']
rewards = ['range_reward', 'entropy_collision_reward']

fig = plt.figure(figsize=(20,16))
i = 1
for s in sensors: 
    for r in rewards: 
        config = {'datetime_start': '2021-06-18T00:00:00', 'reward':r, 'sensor':s, 'target_start': target_start, 'target_speed':1 }
        ax1 = plt.subplot(2,2,i)
        single_plot_combined(ax1, config, metric='theta_err', variance_bars=True)
        i += 1 
        
plt.show()

# %%
print('Captions describe plots starting at top left and moving clockwise \n')
target_start = 78
sensors = ['drone', 'signalstrength']
rewards = ['range_reward', 'entropy_collision_reward']

fig = plt.figure(figsize=(20,16))
i = 1
for s in sensors: 
    for r in rewards: 
        config = {'datetime_start': '2021-06-18T00:00:00', 'reward':r, 'sensor':s, 'target_start': target_start, 'target_speed':1 }
        ax1 = plt.subplot(2,2,i)
        single_plot_combined(ax1, config, metric='r_err', variance_bars=True)
        i += 1 
        
plt.show()

# %% [markdown]
# # Figure 4

# %%
print('Captions describe plots starting at top left and moving clockwise \n')
target_start = 78
sensors = ['drone', 'signalstrength']
rewards = ['range_reward', 'entropy_collision_reward']

fig = plt.figure(figsize=(20,16))
i = 1
for s in sensors: 
    for r in rewards: 
        config = {'datetime_start': '2021-06-18T00:00:00', 'reward':r, 'sensor':s, 'target_start': target_start, 'target_speed':1 }
        ax1 = plt.subplot(2,2,i)
        single_plot_combined(ax1, config, variance_bars=True)
        i += 1 
        
plt.show()

# %%
print('Captions describe plots starting at top left and moving clockwise \n')
target_start = 80
sensors = ['drone', 'signalstrength']
rewards = ['range_reward', 'entropy_collision_reward']

fig = plt.figure(figsize=(20,16))
i = 1
for s in sensors: 
    for r in rewards: 
        config = {'datetime_start': '2021-06-18T00:00:00', 'reward':r, 'sensor':s, 'target_start': target_start, 'target_speed':1 }
        ax1 = plt.subplot(2,2,i)
        single_plot_combined(ax1, config, variance_bars=True)
        i += 1 
        
plt.show()

# %%
target_start = 80
sensors = ['drone', 'signalstrength']
rewards = ['range_reward', 'entropy_collision_reward']

for s in sensors: 
    for r in rewards: 
        config = {'datetime_start': '2021-06-18T00:00:00', 'reward':r, 'sensor':s, 'target_start': target_start, 'target_speed':1 }
        single_plot(config, variance_bars=True)

# %% [markdown]
# # target_start = 50

# %%
target_start = 50
sensors = ['drone', 'signalstrength']
rewards = ['range_reward', 'entropy_collision_reward']

for s in sensors: 
    for r in rewards: 
        config = {'datetime_start': '2021-06-18T00:00:00', 'reward':r, 'sensor':s, 'target_start': target_start, 'target_speed':1 }
        single_plot(config, variance_bars=True)

# %% [markdown]
# # target_start = 75

# %%
target_start = 75
sensors = ['drone', 'signalstrength']
rewards = ['range_reward', 'entropy_collision_reward']

for s in sensors: 
    for r in rewards: 
        config = {'datetime_start': '2021-06-19T00:00:00', 'reward':r, 'sensor':s, 'target_start': target_start, 'target_speed':1 }
        single_plot(config, variance_bars=True)

# %% [markdown]
# # target_start = 90, target_speed = 2

# %%
target_start = 90
sensors = ['drone', 'signalstrength']
rewards = ['range_reward', 'entropy_collision_reward']

for s in sensors: 
    for r in rewards: 
        config = {'datetime_start': '2021-06-19T00:00:00', 'reward':r, 'sensor':s, 'target_start': target_start, 'target_speed':2 }
        single_plot(config, variance_bars=True)

# %% [markdown]
# # target_start = 100

# %%
target_start = 100
sensors = ['drone', 'signalstrength']
rewards = ['range_reward', 'entropy_collision_reward']

for s in sensors: 
    for r in rewards: 
        config = {'datetime_start': '2021-06-19T00:00:00', 'reward':r, 'sensor':s, 'target_start': target_start, 'target_speed':1 }
        single_plot(config, metric='centroid_err', variance_bars=True)

# %% [markdown]
# # target_start = 125

# %%
target_start = 125
sensors = ['drone', 'signalstrength']
rewards = ['range_reward', 'entropy_collision_reward']

for s in sensors: 
    for r in rewards: 
        config = {'datetime_start': '2021-06-19T00:00:00', 'reward':r, 'sensor':s, 'target_start': target_start, 'target_speed':1 }
        single_plot(config, variance_bars=True)

# %% [markdown]
# # target_start = 150

# %%
target_start = 150
sensors = ['drone', 'signalstrength']
rewards = ['range_reward', 'entropy_collision_reward']

for s in sensors: 
    for r in rewards: 
        config = {'datetime_start': '2021-05-09T00:00:00', 'reward':r, 'sensor':s, 'target_start': target_start, 'target_speed':1 }
        single_plot(config, variance_bars=True)

# %% [markdown]
# # Each method (MCTS, DQN each, combined) comparing several starting positions (3 plots)
#
# ## starting positions = [50, 150]

# %% [markdown]
# # figure 5

# %%
sensors = ['drone', 'signalstrength']
rewards = ['range_reward', 'entropy_collision_reward']

for s in sensors: 
    for r in rewards: 
        config = {'datetime_start': '2021-06-19T00:00:00',  'reward':r, 'sensor':s,  'target_speed':1, 'target_start':['75','100', '125']}
        starting_position_plots(config, limit=3)

# %% [markdown]
# # 	Sensor type same methods & starting conditions (MCTS, DQN each, combined) (3 plots)

# %%
sensors = ['drone', 'signalstrength']
rewards = ['range_reward', 'entropy_collision_reward']

for s in sensors: 
    config = {'datetime_start': '2021-06-19T00:00:00','sensor':s, 'target_start':'78', 'target_speed':1 }
    single_plot(config, metric='centroid_err', limit=2)

# %% [markdown]
# # Reward type (3 plots)

# %%
sensors = ['drone', 'signalstrength']
rewards = ['range_reward', 'entropy_collision_reward']
target_speeds = [0,1,2]

for r in rewards: 
    config = {'reward':r, 'target_start':'100', 'target_speed':1 }
    single_plot(config)
